# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as py

# %%
# %matplotlib inline
import seaborn as sns

# %%
loans = pd.read_csv('loan_data.csv')

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
loans.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
loans.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
sns.countplot(x='purpose',data=loans,hue='not.fully.paid',color='red')
py.tight_layout()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 sns.jointplot(y='fico',x='int.rate')
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:2230, in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2227     dropna = True
# ...

# %%
loans[loans['credit.policy']==1]['fico'].hist(bins=35,color='blue',label='1')
loans[loans['credit.policy']==0]['fico'].hist(bins=35,color='red',label='O')
py.legend()
py.figure(figsize=(12,6))

# %%
loans[loans['not.fully.paid']==1]['fico'].hist(bins=35,color='blue',label='1')
loans[loans['not.fully.paid']==0]['fico'].hist(bins=35,color='red',label='O')
py.legend()
py.figure(figsize=(12,6))

# %%
sns.jointplot(x='fico',y='int.rate',data=loans)

# %%
sns.lmplot(y='int.rate',x='fico',data=loans,hue='credit.policy',col='not.fully.paid')

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
cat_feats = ['purpose']

# %%
type(cat_feats)
# Out:
# list

# %%
final_data = pd.get_dummies(loans,columns=cat_feats,drop_first=True)

# %%
from sklearn.model_selection import train_test_split
final_data
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0                 1    0.1189       829.10       11.350407  19.48   737
# 1                 1    0.1071       228.22       11.082143  14.29   707
# 2                 1    0.1357       366.86       10.373491  11.63   682
# 3                 1    0.1008       162.34       11.350407   8.10   712
# 4                 1    0.1426       102.92       11.299732  14.97   667
# ...             ...       ...          ...             ...    ...   ...
# 9573              0    0.1461       344.76       12.180755  10.39   672
# 9574              0    0.1253       257.70       11.141862   0.21   722
# 9575              0    0.1071        97.81       10.596635  13.09   687
# 9576              0    0.1600       351.58       10.819778  19.18   692
# 9577              0    0.1392       853.43       11.264464  16.28   732
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
X = final_data.drop('not.fully.paid',axis=1)
y = final_data['not.fully.paid']


X_train, X_test, y_train, y_test = train_test_split(
 X, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 5314              1    0.1114       262.43       12.072541  15.13   722
# 1831              1    0.1221       433.10       10.971641  16.04   707
# 7267              1    0.1099       180.05       11.002100  17.42   697
# 3720              1    0.1126       821.59       12.487485   5.53   787
# 7319              1    0.0714       111.39       11.034890  16.51   732
# ...             ...       ...          ...             ...    ...   ...
# 5734              1    0.1357       169.85       10.422281  10.71   677
# 5191              1    0.1426       806.19       11.066638  24.88   702
# 5390              1    0.1426       720.43       11.018629  18.85   692
# 860               1    0.1166       247.90       11.002100  19.22   687
# 7270              1    0.1385       327.40       11.407565   4.95   677
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
y_train
# Out:
# 5314    0
# 1831    0
# 7267    0
# 3720    0
# 7319    0
#        ..
# 5734    0
# 5191    0
# 5390    0
# 860     0
# 7270    0
# Name: not.fully.paid, Length: 6417, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))
# Out:
# [[2226  424]
#  [ 405  106]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84      2650
#            1       0.20      0.21      0.20       511
#
#     accuracy                           0.74      3161
#    macro avg       0.52      0.52      0.52      3161
# weighted avg       0.74      0.74      0.74      3161

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test,rfc_pred))
print(classification_report(y_test,rfc_pred))
# Out:
# [[2636   14]
#  [ 502    9]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91      2650
#            1       0.39      0.02      0.03       511
#
#     accuracy                           0.84      3161
#    macro avg       0.62      0.51      0.47      3161
# weighted avg       0.77      0.84      0.77      3161

# %%
final_data['not.fully.paid'].value_counts()
# Out:
# 0    8045
# 1    1533
# Name: not.fully.paid, dtype: int64
